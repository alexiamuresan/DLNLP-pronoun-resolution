# %%
import re
from collections import Counter

# %%
def B3_0(mentions, true_clusters, pred_clusters):
  '''
  Calculates precision, recall, and optionally F1 for the  B3(0) metric,
  based on formulation in https://aclanthology.org/W10-4305.pdf

  returns precision, recall and f1 as lists for the input sentence
  '''

  precision_scores = []
  recall_scores = []
  f1_scores = []

  for mention in mentions:
    precision = 0
    recall = 0

    # finding key and response clusters to look at (first cluster to come up that contains current mention)
    mention_key_cluster = None
    for cluster in true_clusters:
      if mention in cluster:
        mention_key_cluster = cluster
        break
    assert mention_key_cluster, "At least one true cluster must contain mention!"

    mention_pred_cluster = None
    for cluster in pred_clusters:
      if mention in cluster:
        mention_response_cluster = cluster
        break

    intersection_key_response = list((Counter(mention_key_cluster) & Counter(mention_response_cluster)).elements())
    overlap_count = len(intersection_key_response)

    # response cluster could be empty if mention was not predicted for any cluster (twinless mention); in this case precision and recall both at 0
    if mention_response_cluster:
      precision = overlap_count / len(mention_response_cluster)
      recall = overlap_count / len(mention_key_cluster)

    precision_scores.append(precision)
    recall_scores.append(recall)
# Check for zero division
    if precision + recall != 0:
        f1_scores.append((2 * precision * recall) / (precision + recall))
    else:
        f1_scores.append(0.0)
  return precision_scores, recall_scores, f1_scores
def global_B3_0(precision_scores, recall_scores, F1_scores):
  '''
  Calculates global precision, recall and F1 scores based on lists of
  individual B3_0 precision/recall/F1 scores per mention
  '''

  B3_0_precision = sum(precision_scores)/len(precision_scores)
  B3_0_recall = sum(recall_scores)/len(recall_scores)
  B3_0_F1 = sum(F1_scores)/len(F1_scores)

  return B3_0_precision, B3_0_recall, B3_0_F1

# %%
import pandas as pd

# Dummy GAP DataFrame
gap_df = pd.DataFrame({
    'ID': ['test-1', 'test-2'],
    'Pronoun': ['he', 'she'],
    'A': ['John', 'Anna'],
    'B': ['Mike', 'Emily']
})

# Dummy Predictions DataFrame
predictions_df = pd.DataFrame({
    'ID': ['test-1', 'test-2'],
    'A-coref': [False, True],
    'B-coref': [True, False]
})

# Merge the two DataFrames on the "ID" column
merged_df = pd.merge(gap_df, predictions_df, on='ID')

# %%
def generate_clusters_and_mentions(merged_df):
    # Initialize lists to store true and predicted clusters, and mentions for each sentence
    true_clusters_list = []
    pred_clusters_list = []
    mentions_list = []

    # Iterate through the merged DataFrame to generate clusters and mentions
    for _, row in merged_df.iterrows():
        pronoun = row['Pronoun']
        option_a = row['A']
        option_b = row['B']
        a_coref = row['A-coref']
        b_coref = row['B-coref']

        # Mentions for this instance
        mentions = [pronoun, option_a, option_b]

        # True clusters (for demonstration, assuming pronoun co-refers with both options)
        true_cluster = [[pronoun, option_a], [option_b]]

        # Predicted clusters based on model output
        pred_cluster = []
        if a_coref:
            pred_cluster.append([pronoun, option_a])
        elif b_coref:
            pred_cluster.append([pronoun, option_b])
        else:
            pred_cluster.append([pronoun])

        true_clusters_list.append(true_cluster)
        pred_clusters_list.append(pred_cluster)
        mentions_list.append(mentions)

    return true_clusters_list, pred_clusters_list, mentions_list

# Use the function
true_clusters_list, pred_clusters_list, mentions_list = generate_clusters_and_mentions(merged_df)

# Now you can run your B3_0 function for each sentence
for mentions, true_clusters, pred_clusters in zip(mentions_list, true_clusters_list, pred_clusters_list):
    precision_scores, recall_scores, f1_scores = B3_0(mentions, true_clusters, pred_clusters)
    print(f"For mentions {mentions}:")
    print(f"Precision: {precision_scores}, Recall: {recall_scores}, F1: {f1_scores}")
# Out:
# For mentions ['His', 'Bob Suter', 'Dehner']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['him', 'Alonso', 'Alfredo Di St*fano']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Ali Aladhadh', 'Saddam']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Alliata', 'Pisciotta']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Eddie', 'Rock Reilly']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Jewel Staite', 'Keller']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Allison', 'Grace Smythe']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Sophie', 'Jeni']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Malave', 'Greg Joiner']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Cathy Majeski', 'Lorrie Morgan']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Natasha Romanova', 'Johnson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Dolores', 'Rosalinda']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['His', 'Clinton', 'Hubbell']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Alex Bernard', 'Hanson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Nicola Alexis', 'WPC Ruby Buxton']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Spike', 'Buster']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Ann Jillian', 'Ann Miller']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Dunaway', 'Jillian']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Engelke', 'Marge Simpson']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Antonio di Filippo di Lorenzo Niccolini', 'Filippo']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'du Bellay', 'Rabelais']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Caitlin Fairchild', 'Sarah']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Chaucer', 'Aeneas']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Jones', 'Chris Kimsey']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Oliver Turvey', 'Luca Filippi']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Liang Qichao', 'Huang Zongxi']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Kathleen', 'Theresa']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Trudy', 'Juliana']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Karen', 'Juliana']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Arlo', 'Woody Guthrie']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Charles Blitch', 'Young']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Earl of Crawford', 'Phelps']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Michael', 'Tom']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Lisa', 'Tina Cornell']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Lisa', 'Joyce']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Anais', 'Solis']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Ion Mihai Pacepa', 'Aleksandr Sakharovsky']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Thomas Creech', 'Daniel Defoe']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Irish American', 'Michael Madden']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Wiley', 'Hoover']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Scott', 'McGuire']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'George Nattin', 'Ford E. Stinson, Jr.']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Bao Daoyi', 'Pu Wenying']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Katherine Kirkpatrick', 'Susanna']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Michael', 'Peter']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['him', 'Liu Bei', 'Zhuge Liang']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Rudolf Hilferding', 'Friedrich Stampfer']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Samantha', 'Kristen Wiig']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Hallie', 'Kitty']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Dianna', 'Demi Lovato']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Elisabeth', 'Margaret']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Carr', 'Sigourney Weaver']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Stephen Dillane', 'Oldman']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Joan Osborne', 'Ann Marie']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Nikola Stojanovi*', 'Baron Benko']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Bridgette Feltus', 'Rachel Holt']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Flanders', 'Fahl']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Schooley', 'Ryan']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Barbra Ring', 'Gerda']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Nikolai Starikov', 'Putin']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Hilbert', 'Felix Klein']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Ralph Fults', 'Raymond Hamilton']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Cooke', 'Virginia Woolf']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Small', 'Matthew Hall']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['He', 'Philippe Burty', 'Eug*ne Delacroix']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Emerson Fittipaldi', 'Helmut Marko']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Chaplin', 'Hoover']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Hodson', 'Marie Rambert']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Thomas', 'Rocky Sullivan']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Jim Lee', 'Booth']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Frey', 'Chairman of the Board of Supervisors']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Jenee Welsh', 'Jennifer']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Roseanne', 'Darlene']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Werner', 'Barr']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Valerie', 'Valeria']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Jimmy Kemp', 'Jack']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'White', 'Hillary Clinton']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Hooker', 'Robert Caspary']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Handwerker', 'Feltman']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Joy', 'Helen']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Kimiko', 'Francisca']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Nick Stevens', 'Murphy']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Liv', 'Olivia']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Lasseter', 'Raoul Servais']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Mike Clark', 'Shatner']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Shatner', 'Andre']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Altman', 'Anna-Marie Erd*dy']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Brown', 'Finlay Currie']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Salcedo', 'Zambrano']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Emerson', 'Ramses']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Maldini', 'Gourcuff']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'George Clinton', 'Montesquieu']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Joe Li', 'Gordon Landon']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Vendera', 'Roger Schwenke']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Dylan', 'Nash']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Fritzsch', 'Gerhard Prautzsch']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Francesco Carlo Dalatri', 'John Peel']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Marina Scalafiotti', 'Amelia Careggio']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'God', 'Elias']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['Her', 'Mary Shelley', 'Jane Austen']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['His', 'Clark Gable', 'Busse']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Bart Allen', 'Gallner']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Jackson', 'Pelinka']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Liza Maza', 'Filipina']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Maria Venus Raj', 'Helen Nicolette Henson']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Andy', 'Charlie']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Mantlo', 'Gerber']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Caitlin Stasey', 'Rachel Kinski']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Mahendra Roy', 'Raju']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Alice Randall', 'Trisha Yearwood']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Alban Butler', 'John']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['him', 'De Luna', 'Governor Perry']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Popp', 'Nancy']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Vinnie Van Lowe', 'Keith']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Van Clemmons', 'Vincent']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Veronica', 'Meg']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Rowland', 'Amos']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Liam Davis', 'Big Star']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Stanley Loomis', 'John Allen Gable']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Welles', 'Roger Hill']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Roger Williams', 'Chad Brown']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Amanda', 'Cara']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Mary', 'Louise']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Terry Pole', 'Bill']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Dave Fane', 'Ron']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Cruz', 'Tim Hudson']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Jane Russell', 'Marilynn Hinton']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', '*amon de Valera', 'McGarry']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Johnny', 'Leroy']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Laura', 'Angela Viracco']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Charles Manson', 'Young']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Cato', 'Seeff']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Groening', 'Homer']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Rosebaum', 'Ruth']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'King George VI', 'Piggott']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Jennifer James', 'Suzanne Cox']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Dave Sinclair', 'John Everett']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Annabelle', 'Mia']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Constantina', 'Sophia']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Rooney', 'Stretford']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Iya Patarkatsishvili', 'Inna']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Christina Regina Si*berg', "Christina Elisabeth d'Albedyll"]:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Baer', 'Jane Addams']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Stephen Thomas Erlewine', 'Stewart Mason']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Raskin', 'William Goldenberg']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Brandt 1873', 'Giuseppe Cortesi']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Paul', 'Abraham']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Lewis', 'Gary Anderson']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['His', 'Aleksander Chodkiewicz', 'Ostrogski']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['She', 'Kay Winthrop', 'Sarah Barroll Thayer']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Reck', 'Kahn']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Fowler', 'Robert Howard']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Allison Danger', 'Rogers']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Tatyana Khodorovich', 'Tatyana Velikanova']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Dick Morris', 'Eliot Spitzer']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Alicia', 'Petra Moritz']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Diane', 'Alicia']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Jason', 'Peter']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Zhu', 'Zhou']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Johnny Coe', 'Jock Gourlay']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Bilbo', 'Gandalf']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Maryse', 'James']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Jackson', 'Whittaker Chambers']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Donaldson', 'Charlie Parker']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Sean', 'Takashi']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Sean', 'Takashi']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Damon Albarn', 'Frank Hewetson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Sarantidis', 'Karolos Papoulias']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Luigi Carpentieri', 'Ernesto Gastaldi']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Philip Ellender', 'Harry Reid']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Graham-Cassidy', 'Roberts']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Lee Kong Chian', 'Tan Kah Kee']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Smith', 'Tully Blanchard']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Regent Morton', 'George Home']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Bernard Lewis', 'Mustafa Kemal']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Postrel', 'Sally Satel']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Clapp', 'Robert Menzies']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Carla', 'Ellen']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Pettitte', 'McNamee']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', "O'Neill", 'Olson']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Don Getty', 'Anderson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Liz', 'Audrey']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Russell', 'Adam']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Eliza Collins', 'Charlotte Eliza Cox']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Julie', 'Fate']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Richard Wagner', 'Ferdinand Avenarius']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Flavius Josephus', 'Alexander Jannaeus']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Johnnie Walker', 'Richard Preston']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Fermina', 'Rosalind Cartlidge']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['him', 'Philip James', 'Pusztai']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Gina Kabir Bedi', 'Gina']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Natasha', 'Linda']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Alfred Hitchcock', 'Derrick De Marney']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Mel', 'Harth']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Erin Fray', 'Erin']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Joan Shelley Rubin', 'Widdemer']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Zbigniew Drzewiecki', 'Kazimierz Sikorski']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'John Hawkins', 'Nelson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Peggy', 'Marcy']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Marcy', 'Keri Russell']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Bud', 'Al']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Vic Sotto', 'Ritchie']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'John Hartwell', 'Swann']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Hermann Nicolai', 'Otto R*ssler']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Jones', 'Houston McTear']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Howard M. Colvin', 'Nicholson']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Shackelford', 'Ray Gordon']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Rafael Coelho Luiz', 'Leo Moura']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'James Best', 'Stephen Jones']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Padbury', 'Cathy Vespers']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Stephen King', 'Patterson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Belden', 'Lou Marini']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Cotterill', 'Elizabeth']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Elizabeth', 'Judith Isham']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Sam Hammam', 'Kavanagh']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Ravi', 'Police Inspector']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Christina Aguilera', 'Brown']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Eigenmann', 'Rosa Smith']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Josephine', 'Elizabeth']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Philip Arnold', 'Sammy']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Lewis Milestone', 'Brown']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Clarke', 'Rupert Fryer']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Reza', 'Abu Naser']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Katie', 'Jo']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Antiochus', 'Zeus Olympios']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Norma', 'Vicki']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Charles', 'Charles Martel']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Stephen Holden', 'Gideon']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Arona', 'Mezger']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Dick', 'Bruce after Two-Face']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Michael Keaton', 'Batman']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Louie Castaneda', "Boss D'Angelo"]:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Dereschuk', 'Jessica Dereschuk Day']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Fiona Harrision', 'Zuber']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Louis Slesin', 'Robert L. Park']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'William Sahakian', 'John Locke']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Caldwell', 'Daniel Ringo']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Appolyon', 'Charon']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Ashiq Q*rib', 'Mikhail Lermontov']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['His', 'Betsy', 'Marshall']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Elizabeth Castelli', 'Ann Whitney Olin Professor of Religion']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Byron White', 'James Schroeder']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Joel Savoy', 'Lawrence Migdale']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Kolosci', 'Danzig']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Jeff Jensen', 'Lindelof']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Isaac P. Rodman', 'Arnold']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Prince', 'Elton John']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Thelma Barlow', 'Mavis']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Scholl', 'Boos']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Christina Lee', 'Brown']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Lawrence Russel Brewer', 'James Byrd Jr.']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Gibbard', 'Michael Dummett']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Marleen Vaesen', 'Sara Lee']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Pollock', 'Tom']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Davey', 'William Pryce']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Ferdinand Domela Nieuwenhuis', 'De Roos']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Valerie', 'Gibson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Signer', 'Bill Bolling']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Ian Anderson', 'Jethro Tull']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Michael Quinn Sullivan', 'Smith']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Dick Lee', 'Thorp']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['him', 'Ben', 'Patrick Troughton']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'James Gang', 'Kenner']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Roy Westerfield', 'Bruce Halker']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Madame Leota', 'Sarah']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Aaron A.', 'Lord Dunswallop']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Christopher Heyerdahl', 'Dr. Magnus']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Kali', 'Helen']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Chesney', 'Foliot']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Snape', 'Harry']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Jain', 'Willis']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Alice Davie', 'Betty']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Helen Holmes', 'Anna Q']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Phoebe Apperson Hearst', 'Millicent']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Alice Taylor Huyler', 'Ada Mumford Farr']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Waleran', 'Frederick I, Duke of Lorraine']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Hema', 'Shobha']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Murer', 'Yelena Isinbayeva']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Erika Pluhar', 'Anna']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Catholic Bishop', 'James Michael Liston']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['him', 'Brother Treacy', 'Patrick Moran']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Anna MacIntosh', 'Mildred Vergosen']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Clara Bow', 'White']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Ted Whitten', 'Ion']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Leyla', 'Tala']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Hult Ganis', 'Sally Field']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Martin', 'Gladys Moon']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['His', 'Footman', 'Alf Stokes']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['She', 'Alison Darren', 'Cissy']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Ned', 'Harry Donnan']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Stoessel', 'Susana Gimen*z']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Morris', 'Travis Henry']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Frederick', 'Henry']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Milgrim', 'Root-Tilden Scholar']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Julie Harris', 'Emily Dickinson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Schilling', 'Tadashi Sawashima']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Yung Carter', 'Anderson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Michel Foucault', 'Ernest Shackleton']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Sandra', 'Claire Bennet']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Octavian', 'Antony']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Evans', 'John Carisi']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Maurice Ravel', 'Sargeant']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['him', 'Paul Simon', 'Georges']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Daniel Wallace', 'Gery']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Kirk Douglas', 'Marquand']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Sher Shah Suri', 'Humayun']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Van Dorn', 'Ross']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Robert', 'James L. Brooks']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Nick Clegg', 'David Laws']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Matthew', 'John']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Schuyler Miller', 'Finney']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Dick MacPherson', 'Collier']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Sharna Burgess', 'Jenna Johnson']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Margaret Tucker', 'Teresa Middleton Clements']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Broughton', 'Travis Browne']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Sudhakar', 'Mangal']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Bram Stoker Award', 'Joe McKinney']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Balog', 'Irving Penn']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Bork', 'Reagan']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Curtis', 'Jemmott']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Dalton McGuinty', 'Sousa']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['him', 'Monk', 'Roan']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Alice', 'Maya']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Wang', 'Dai']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Rod Stradling', 'Edward II']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Webb', 'Danny']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['his', 'Michael Winner', 'White']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Elizabeth', 'Catherine']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Catherine', 'Anna']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Piero Gherardi', 'Federico Fellini']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Brenda Blethyn', 'Goodwin']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Martha Longhurst', 'Carol']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'John', 'Alexios I Komnenos']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Taylor', 'Matthew Webb']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Troy', 'Perry']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['He', 'Piatti', 'Carlos Prieto']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Roland Huntford', 'Hussey']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['he', 'Nicholas II of Russia', 'Pyotr Ivanovich Zamyatin']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Lily', 'Faith']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['him', 'Dawkins', 'Lautenberg']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Normand', 'Busch']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Cassel', 'Jason Taylor']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['he', 'Tessin', 'Gustav III']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Louisa Ulrika', 'The Queen']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Montgomery', 'Chris Milfred']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Louise', 'Dorothy']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['His', 'Rhys', 'Dave']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Dave', 'Josh']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Williams', 'Trey Lewis']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Kate', 'Nina']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['his', 'Paul Hyett', 'Ed Speleers']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Rusty Staub', 'Robertson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Amanda', 'Betty']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['he', 'Goodall', 'George Orwell']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Alain-S*bastien Le Breton', 'Jes*s Serrano Pastor']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['him', 'Morse', 'Gillan']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Andrews', 'Bobby Bowden']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Stephanie Delacour', 'Kristeva']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['He', 'Michael', 'Tony Hillerman']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Shirley Temple', 'Irene']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Constable', 'Jones']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Hayley', 'Tess']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['his', 'Barnum', 'Tom Walsh']:
# ...
# For mentions ['her', 'Mary', 'Davidson']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Luisa Maria', 'Princess Astrid of Belgium']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Doris Lessing', 'Marleen S']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Anjali', 'Sarah Harris']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Mary Jephson', 'Mary Villiers']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Joyce Anderson', 'Lucy Elanor Perry']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Tickell', 'Linda Thompson']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Joan Baez', 'Diana Ross']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Isabella', 'Beatrice']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Kay', 'Grace']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Jillian Karr', 'Tintori']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Graf', 'Pam Shriver']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Elizabeth', 'Crooke']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['Her', 'Palmer', 'Ida Clough']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Vivien', 'Velma']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Malala', 'Flor']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Tyra Banks', 'Ammerman']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Mount', 'Stella McCartney']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Jane Lane', 'Anne Bagot']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Brittany Pierce', 'Brittany']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Brittany', 'Alma']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Mary Holford', 'Elizabeth Mainwaring']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['She', 'Violeta Parra', 'Sosa']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Angela', 'Anna']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Sandie Pendleton', "Catherine ``Kate'' Carter Corbin"]:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Azarenka', 'Ana Ivanovic']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Harriet', 'Foote']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Bobbi', 'Edna May']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Olsen', 'Christine Payne']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Isabel', 'Muriel']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Kozlova', 'Anna Kisselgoff']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Rus', 'Mirjana Lu*i*']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Hilary Spurling', 'Delectorskaya']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Peggy Parish', 'Amelia Bedelia']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'MacColl', 'Oscar']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Olga', 'Carol']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Judy Gerstel', 'Mina Shum']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Vernon', 'Ellen']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Teagan', 'Lisa Marie Presley']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Revathi', 'Shilpa Shetty']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Victoria', 'Chloe']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['Her', 'Telma Hopkins', 'Shirley Murdock']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Sabrina Rubin Erdely', 'Kinser']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Sybil Marjorie Cuffe', 'Lady Margaret Joan Lascelles']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Ursula Hegi', 'Patricia Highsmith']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['She', 'Agnes Meyer', 'Katharine Rhoades']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Ramona', 'Beatrice Quimby']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Tori', 'Beck']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Tori', 'Beck']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['She', 'Raina Hein', 'White']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Petra', 'Wicked Witch']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Anne Sofie von Berckentin', 'Caroline Matilda']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Martines', 'Stella Lelouch']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Shirazi', 'Delphine Halgand']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Maribel', 'Rosa']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Ray', 'Kelli Hill']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Hema Malini', 'Razia Sultan']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Dent', 'Eleanor Brown']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Rand', 'Ann Corio']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Elizabeth Gaskell', 'Shirley']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Shirley', 'Bront*']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Fiona', 'Nuala Anne']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['hers', 'Vera Lachmann', 'Nelly Sachs']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Maria', 'Johanna']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Holly', 'Juliana']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Bea Feitler', 'Ruth Ansel']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Jeri', 'Gloria']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Gresser', 'Lyudmila Rudenko']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Victoria Mary Clarke', "O'Sullivan"]:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Hazzard', 'Williamson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Violante Beatrice', 'Anna Maria']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Marulanda', 'Marcela Sarmiento']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Sims', 'Jane Annie']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Joanne Evans', 'Naomi']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Overton', 'Amelia Charlesworth']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Rosalind Rosenberg', 'Gildersleeve']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Agnes Nixon', 'Broderick']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Queen Sibylla', 'Constance']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Kate', 'Nora']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Millicent', 'Brooke']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Dian Fossey', 'Agathe Uwilingiyimana']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Eva', 'Vera']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['She', 'Sarah Dash', 'Patti Scialfa']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['her', 'Mahon', 'Thompson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Jenny Jochens', 'Motz']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Kreuk', 'Lana']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Vittoria Capoccii', 'Laura']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Mrs Jacobsson', 'Jane Goodall']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Aretha Franklin', 'Missy Elliott']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['She', 'Barbra Streisand', 'Ann Powers']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Asma', 'Arwa']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Jovanovski', 'Vera Zvonareva']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Princess Margaret', 'Mary']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Jennie Garth', 'Kelly']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Lady Dedlock', 'Esther']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Liu', 'Gu Long']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Kayla', 'Camryn']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Sanchez', 'Chelsea Caswell']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Catherine', 'Susan Higginbotham']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Elvira', 'Morvan']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Donna', 'Christine']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Norah Lofts', 'Caroline Matilda']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['Her', 'Megan Macqueen', 'Cook']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Silvia', 'Carola']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Mary', 'Thomasine Clopton']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['Her', 'Margaret Tyndal', 'Anne Egerton']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Ruth', 'Naomi']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['she', 'Dolly', 'Sadie']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['she', 'Elizabeth Mann', 'Mabel Martha']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Elaine Z. Skinner', 'Civille']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['She', 'Vivian Colobella', 'Johnson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Holly Stevens', 'Elsie']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Mia Algotti', 'Miss Foozie']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['her', 'Goolagong Cawley', 'Venus Williams']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Goolagong Cawley', 'Peggy Michel']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Esther Sheryl Wood', 'Barbara Morgan']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['She', 'Kayla', 'Natasha Henstridge']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['she', 'Irma', 'Bergen']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['her', 'Vicky Austin', "Polly O'Keefe"]:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]

# %%
B3_0(mentions, true_clusters, pred_clusters)
# Out:
# ([1.0, 1.0, 0.0], [1.0, 1.0, 0.0], [1.0, 1.0, 0.0])

# %%
gap_file = "gap-test.tsv"
predictions_file = "predictions-test.tsv"

# %%
gap_df.head(1)
# Out:
#        ID Pronoun     A     B
# 0  test-1      he  John  Mike

# %%
# Reading GAP DataFrame from a TSV file
gap_df = pd.read_csv(gap_file, sep='\t')
gap_df.rename(columns={'A-coref': 'gold_A-coref', 'B-coref': 'gold_B-coref'},inplace=True)# Reading Predictions DataFrame from a TSV file
predictions_df = pd.read_csv(predictions_file, sep='\t')

# Merge the two DataFrames on the "ID" column
merged_df = pd.merge(gap_df, predictions_df, on='ID')

# Display the first few rows to check
merged_df.head(1)
# Out:
#        ID                                               Text Pronoun  \
# 0  test-1  Upon their acceptance into the Kontinental Hoc...     His
#
#    Pronoun-offset          A  A-offset  gold_A-coref       B  B-offset  \
# 0             383  Bob Suter       352         False  Dehner       366
#
#    gold_B-coref                                         URL  A-coref  B-coref
# 0          True  http://en.wikipedia.org/wiki/Jeremy_Dehner    False     True

# %%
true_clusters_list, pred_clusters_list, mentions_list = generate_clusters_and_mentions(merged_df)
# B3_0(mentions_list, true_clusters_list, pred_clusters_list)

# %%
total_precision_scores = []
total_recall_scores = []
total_f1_scores = []
# Now you can run your B3_0 function for each sentence
for mentions, true_clusters, pred_clusters in zip(mentions_list, true_clusters_list, pred_clusters_list):
    # print(f"Mentions {mentions}, true clusters {true_clusters}, predicted clusters {pred_clusters}")
    try:
        precision_scores, recall_scores, f1_scores = B3_0(mentions, true_clusters, pred_clusters)
        total_precision_scores += precision_scores
        total_recall_scores += recall_scores
        total_f1_scores += f1_scores
    except:
        print(f"Mentions {mentions}, true clusters {true_clusters}, predicted clusters {pred_clusters}")

# %%
global_precision, global_recall, global_f1 = global_B3_0(total_precision_scores, total_recall_scores, total_f1_scores)

# Format the results as a string
results_str = f"{gap_file} Global B3 Scores:\n"
results_str += f"Precision: {global_precision:.2f}\n"
results_str += f"Recall: {global_recall:.2f}\n"
results_str += f"F1 Score: {global_f1:.2f}"

# Print and share the results
print(results_str)

# If you want to save the results to a text file
with open(gap_file+"_global_B3_scores.txt", "w") as f:
    f.write(results_str)
# Out:
# gap-test.tsv Global B3 Scores:
# Precision: 0.60
# Recall: 0.61
# F1 Score: 0.59

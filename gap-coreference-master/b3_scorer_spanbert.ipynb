# %%
import re
from collections import Counter

# %%
def B3_0(mentions, true_clusters, pred_clusters):
  '''
  Calculates precision, recall, and optionally F1 for the  B3(0) metric,
  based on formulation in https://aclanthology.org/W10-4305.pdf

  returns precision, recall and f1 as lists for the input sentence
  '''

  precision_scores = []
  recall_scores = []
  f1_scores = []

  for mention in mentions:
    precision = 0
    recall = 0

    # finding key and response clusters to look at (first cluster to come up that contains current mention)
    mention_key_cluster = None
    for cluster in true_clusters:
      if mention in cluster:
        mention_key_cluster = cluster
        break
    assert mention_key_cluster, "At least one true cluster must contain mention!"

    mention_pred_cluster = None
    for cluster in pred_clusters:
      if mention in cluster:
        mention_response_cluster = cluster
        break

    intersection_key_response = list((Counter(mention_key_cluster) & Counter(mention_response_cluster)).elements())
    overlap_count = len(intersection_key_response)

    # response cluster could be empty if mention was not predicted for any cluster (twinless mention); in this case precision and recall both at 0
    if mention_response_cluster:
      precision = overlap_count / len(mention_response_cluster)
      recall = overlap_count / len(mention_key_cluster)

    precision_scores.append(precision)
    recall_scores.append(recall)
# Check for zero division
    if precision + recall != 0:
        f1_scores.append((2 * precision * recall) / (precision + recall))
    else:
        f1_scores.append(0.0)
  return precision_scores, recall_scores, f1_scores
def global_B3_0(precision_scores, recall_scores, F1_scores):
  '''
  Calculates global precision, recall and F1 scores based on lists of
  individual B3_0 precision/recall/F1 scores per mention
  '''

  B3_0_precision = sum(precision_scores)/len(precision_scores)
  B3_0_recall = sum(recall_scores)/len(recall_scores)
  B3_0_F1 = sum(F1_scores)/len(F1_scores)

  return B3_0_precision, B3_0_recall, B3_0_F1

# %%
import pandas as pd

# Dummy GAP DataFrame
gap_df = pd.DataFrame({
    'ID': ['test-1', 'test-2'],
    'Pronoun': ['he', 'she'],
    'A': ['John', 'Anna'],
    'B': ['Mike', 'Emily']
})

# Dummy Predictions DataFrame
predictions_df = pd.DataFrame({
    'ID': ['test-1', 'test-2'],
    'A-coref': [False, True],
    'B-coref': [True, False]
})

# Merge the two DataFrames on the "ID" column
merged_df = pd.merge(gap_df, predictions_df, on='ID')

# %%
def generate_clusters_and_mentions(merged_df):
    # lists to store true and predicted clusters, and mentions for each sentence
    true_clusters_list = []
    pred_clusters_list = []
    mentions_list = []
    gender_list = []
    # Iterate through the merged DataFrame to generate clusters and mentions
    for _, row in merged_df.iterrows():
        pronoun = row['Pronoun']
        option_a = row['A']
        option_b = row['B']
        a_coref = row['A-coref']
        b_coref = row['B-coref']

        # mentions for this instance
        mentions = [pronoun, option_a, option_b]

        # true clusters 
        true_cluster = [[pronoun, option_a], [option_b]]
        gendered_pronouns = row['Pronoun_old'] if 'Pronoun_old' in merged_df.columns else row['Pronoun']
        gendered_pronouns = gendered_pronouns.lower()
        if gendered_pronouns == 'he' or gendered_pronouns == 'his' or gendered_pronouns == 'him':
            gender_list.append('M')
        elif gendered_pronouns == 'she' or gendered_pronouns == 'her' or gendered_pronouns == 'hers':
             gender_list.append('F')
        # pred clusters based on model output
        pred_cluster = []
        if a_coref:
            pred_cluster.append([pronoun, option_a])
        elif b_coref:
            pred_cluster.append([pronoun, option_b])
        else:
            pred_cluster.append([pronoun])

        true_clusters_list.append(true_cluster)
        pred_clusters_list.append(pred_cluster)
        mentions_list.append(mentions)

    return true_clusters_list, pred_clusters_list, mentions_list, gender_list


true_clusters_list, pred_clusters_list, mentions_list, gender_list = generate_clusters_and_mentions(merged_df)

# run B3_0 function for each sentence
for mentions, true_clusters, pred_clusters in zip(mentions_list, true_clusters_list, pred_clusters_list):
    precision_scores, recall_scores, f1_scores = B3_0(mentions, true_clusters, pred_clusters)
    print(f"For mentions {mentions}:")
    print(f"Precision: {precision_scores}, Recall: {recall_scores}, F1: {f1_scores}")
# Out:
# For mentions ['their', 'Bob Suter', 'Dehner']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['them', 'Alonso', 'Alfredo Di St*fano']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Ali Aladhadh', 'Saddam']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Alliata', 'Pisciotta']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Eddie', 'Rock Reilly']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Jewel Staite', 'Keller']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Allison', 'Grace Smythe']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Sophie', 'Jeni']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Malave', 'Greg Joiner']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Cathy Majeski', 'Lorrie Morgan']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Natasha Romanova', 'Johnson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Dolores', 'Rosalinda']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Clinton', 'Hubbell']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Alex Bernard', 'Hanson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Nicola Alexis', 'WPC Ruby Buxton']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Spike', 'Buster']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Ann Jillian', 'Ann Miller']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Dunaway', 'Jillian']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Engelke', 'Marge Simpson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Antonio di Filippo di Lorenzo Niccolini', 'Filippo']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'du Bellay', 'Rabelais']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Caitlin Fairchild', 'Sarah']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Chaucer', 'Aeneas']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Jones', 'Chris Kimsey']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Oliver Turvey', 'Luca Filippi']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Liang Qichao', 'Huang Zongxi']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Kathleen', 'Theresa']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Trudy', 'Juliana']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Karen', 'Juliana']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Arlo', 'Woody Guthrie']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Charles Blitch', 'Young']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Earl of Crawford', 'Phelps']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Michael', 'Tom']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Lisa', 'Tina Cornell']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Lisa', 'Joyce']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Anais', 'Solis']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Ion Mihai Pacepa', 'Aleksandr Sakharovsky']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Thomas Creech', 'Daniel Defoe']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Irish American', 'Michael Madden']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Wiley', 'Hoover']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Scott', 'McGuire']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'George Nattin', 'Ford E. Stinson, Jr.']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Bao Daoyi', 'Pu Wenying']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Katherine Kirkpatrick', 'Susanna']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Michael', 'Peter']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Liu Bei', 'Zhuge Liang']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Rudolf Hilferding', 'Friedrich Stampfer']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Samantha', 'Kristen Wiig']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Hallie', 'Kitty']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Dianna', 'Demi Lovato']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Elisabeth', 'Margaret']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Carr', 'Sigourney Weaver']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Stephen Dillane', 'Oldman']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Joan Osborne', 'Ann Marie']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Nikola Stojanovi*', 'Baron Benko']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Bridgette Feltus', 'Rachel Holt']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Flanders', 'Fahl']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Schooley', 'Ryan']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Barbra Ring', 'Gerda']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Nikolai Starikov', 'Putin']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Hilbert', 'Felix Klein']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Ralph Fults', 'Raymond Hamilton']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Cooke', 'Virginia Woolf']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['them', 'Small', 'Matthew Hall']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Philippe Burty', 'Eug*ne Delacroix']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['them', 'Emerson Fittipaldi', 'Helmut Marko']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Chaplin', 'Hoover']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Hodson', 'Marie Rambert']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Thomas', 'Rocky Sullivan']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Jim Lee', 'Booth']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Frey', 'Chairman of the Board of Supervisors']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Jenee Welsh', 'Jennifer']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Roseanne', 'Darlene']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Werner', 'Barr']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Valerie', 'Valeria']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Jimmy Kemp', 'Jack']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'White', 'Hillary Clinton']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Hooker', 'Robert Caspary']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Handwerker', 'Feltman']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Joy', 'Helen']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Kimiko', 'Francisca']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Nick Stevens', 'Murphy']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Liv', 'Olivia']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Lasseter', 'Raoul Servais']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Mike Clark', 'Shatner']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Shatner', 'Andre']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Altman', 'Anna-Marie Erd*dy']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Brown', 'Finlay Currie']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Salcedo', 'Zambrano']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Emerson', 'Ramses']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Maldini', 'Gourcuff']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'George Clinton', 'Montesquieu']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Joe Li', 'Gordon Landon']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Vendera', 'Roger Schwenke']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Dylan', 'Nash']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Fritzsch', 'Gerhard Prautzsch']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Francesco Carlo Dalatri', 'John Peel']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Marina Scalafiotti', 'Amelia Careggio']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'God', 'Elias']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Mary Shelley', 'Jane Austen']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Clark Gable', 'Busse']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Bart Allen', 'Gallner']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Jackson', 'Pelinka']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Liza Maza', 'Filipina']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Maria Venus Raj', 'Helen Nicolette Henson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Andy', 'Charlie']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Mantlo', 'Gerber']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Caitlin Stasey', 'Rachel Kinski']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Mahendra Roy', 'Raju']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Alice Randall', 'Trisha Yearwood']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Alban Butler', 'John']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'De Luna', 'Governor Perry']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Popp', 'Nancy']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Vinnie Van Lowe', 'Keith']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Van Clemmons', 'Vincent']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Veronica', 'Meg']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Rowland', 'Amos']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Liam Davis', 'Big Star']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Stanley Loomis', 'John Allen Gable']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Welles', 'Roger Hill']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Roger Williams', 'Chad Brown']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Amanda', 'Cara']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Mary', 'Louise']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Terry Pole', 'Bill']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Dave Fane', 'Ron']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Cruz', 'Tim Hudson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Jane Russell', 'Marilynn Hinton']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', '*amon de Valera', 'McGarry']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Johnny', 'Leroy']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Laura', 'Angela Viracco']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Charles Manson', 'Young']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Cato', 'Seeff']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Groening', 'Homer']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Rosebaum', 'Ruth']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'King George VI', 'Piggott']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Jennifer James', 'Suzanne Cox']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Dave Sinclair', 'John Everett']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Annabelle', 'Mia']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Constantina', 'Sophia']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Rooney', 'Stretford']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Iya Patarkatsishvili', 'Inna']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Christina Regina Si*berg', "Christina Elisabeth d'Albedyll"]:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Baer', 'Jane Addams']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Stephen Thomas Erlewine', 'Stewart Mason']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Raskin', 'William Goldenberg']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Brandt 1873', 'Giuseppe Cortesi']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Paul', 'Abraham']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Lewis', 'Gary Anderson']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Aleksander Chodkiewicz', 'Ostrogski']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Kay Winthrop', 'Sarah Barroll Thayer']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Reck', 'Kahn']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Fowler', 'Robert Howard']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Allison Danger', 'Rogers']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Tatyana Khodorovich', 'Tatyana Velikanova']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['them', 'Dick Morris', 'Eliot Spitzer']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Alicia', 'Petra Moritz']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Diane', 'Alicia']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Jason', 'Peter']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Zhu', 'Zhou']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Johnny Coe', 'Jock Gourlay']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Bilbo', 'Gandalf']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Maryse', 'James']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Jackson', 'Whittaker Chambers']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Donaldson', 'Charlie Parker']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Sean', 'Takashi']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Sean', 'Takashi']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Damon Albarn', 'Frank Hewetson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Sarantidis', 'Karolos Papoulias']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Luigi Carpentieri', 'Ernesto Gastaldi']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Philip Ellender', 'Harry Reid']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Graham-Cassidy', 'Roberts']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Lee Kong Chian', 'Tan Kah Kee']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Smith', 'Tully Blanchard']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Regent Morton', 'George Home']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Bernard Lewis', 'Mustafa Kemal']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Postrel', 'Sally Satel']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Clapp', 'Robert Menzies']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Carla', 'Ellen']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Pettitte', 'McNamee']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', "O'Neill", 'Olson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Don Getty', 'Anderson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Liz', 'Audrey']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Russell', 'Adam']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Eliza Collins', 'Charlotte Eliza Cox']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Julie', 'Fate']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Richard Wagner', 'Ferdinand Avenarius']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Flavius Josephus', 'Alexander Jannaeus']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Johnnie Walker', 'Richard Preston']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Fermina', 'Rosalind Cartlidge']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Philip James', 'Pusztai']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Gina Kabir Bedi', 'Gina']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Natasha', 'Linda']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Alfred Hitchcock', 'Derrick De Marney']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Mel', 'Harth']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Erin Fray', 'Erin']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Joan Shelley Rubin', 'Widdemer']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Zbigniew Drzewiecki', 'Kazimierz Sikorski']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'John Hawkins', 'Nelson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Peggy', 'Marcy']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Marcy', 'Keri Russell']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Bud', 'Al']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Vic Sotto', 'Ritchie']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'John Hartwell', 'Swann']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Hermann Nicolai', 'Otto R*ssler']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Jones', 'Houston McTear']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Howard M. Colvin', 'Nicholson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Shackelford', 'Ray Gordon']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Rafael Coelho Luiz', 'Leo Moura']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'James Best', 'Stephen Jones']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Padbury', 'Cathy Vespers']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Stephen King', 'Patterson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Belden', 'Lou Marini']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Cotterill', 'Elizabeth']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Elizabeth', 'Judith Isham']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Sam Hammam', 'Kavanagh']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Ravi', 'Police Inspector']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Christina Aguilera', 'Brown']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Eigenmann', 'Rosa Smith']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Josephine', 'Elizabeth']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Philip Arnold', 'Sammy']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Lewis Milestone', 'Brown']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Clarke', 'Rupert Fryer']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Reza', 'Abu Naser']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Katie', 'Jo']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Antiochus', 'Zeus Olympios']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Norma', 'Vicki']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Charles', 'Charles Martel']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Stephen Holden', 'Gideon']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Arona', 'Mezger']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Dick', 'Bruce after Two-Face']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Michael Keaton', 'Batman']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Louie Castaneda', "Boss D'Angelo"]:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Dereschuk', 'Jessica Dereschuk Day']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Fiona Harrision', 'Zuber']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Louis Slesin', 'Robert L. Park']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'William Sahakian', 'John Locke']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Caldwell', 'Daniel Ringo']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Appolyon', 'Charon']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Ashiq Q*rib', 'Mikhail Lermontov']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Betsy', 'Marshall']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Elizabeth Castelli', 'Ann Whitney Olin Professor of Religion']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Byron White', 'James Schroeder']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Joel Savoy', 'Lawrence Migdale']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Kolosci', 'Danzig']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Jeff Jensen', 'Lindelof']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Isaac P. Rodman', 'Arnold']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Prince', 'Elton John']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Thelma Barlow', 'Mavis']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Scholl', 'Boos']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Christina Lee', 'Brown']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Lawrence Russel Brewer', 'James Byrd Jr.']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Gibbard', 'Michael Dummett']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Marleen Vaesen', 'Sara Lee']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Pollock', 'Tom']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Davey', 'William Pryce']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Ferdinand Domela Nieuwenhuis', 'De Roos']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Valerie', 'Gibson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Signer', 'Bill Bolling']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Ian Anderson', 'Jethro Tull']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['them', 'Michael Quinn Sullivan', 'Smith']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Dick Lee', 'Thorp']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['them', 'Ben', 'Patrick Troughton']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'James Gang', 'Kenner']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Roy Westerfield', 'Bruce Halker']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Madame Leota', 'Sarah']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Aaron A.', 'Lord Dunswallop']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Christopher Heyerdahl', 'Dr. Magnus']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Kali', 'Helen']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Chesney', 'Foliot']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Snape', 'Harry']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Jain', 'Willis']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Alice Davie', 'Betty']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Helen Holmes', 'Anna Q']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Phoebe Apperson Hearst', 'Millicent']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Alice Taylor Huyler', 'Ada Mumford Farr']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Waleran', 'Frederick I, Duke of Lorraine']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Hema', 'Shobha']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Murer', 'Yelena Isinbayeva']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Erika Pluhar', 'Anna']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Catholic Bishop', 'James Michael Liston']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['them', 'Brother Treacy', 'Patrick Moran']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Anna MacIntosh', 'Mildred Vergosen']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Clara Bow', 'White']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Ted Whitten', 'Ion']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Leyla', 'Tala']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Hult Ganis', 'Sally Field']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Martin', 'Gladys Moon']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Footman', 'Alf Stokes']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Alison Darren', 'Cissy']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Ned', 'Harry Donnan']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Stoessel', 'Susana Gimen*z']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Morris', 'Travis Henry']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Frederick', 'Henry']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Milgrim', 'Root-Tilden Scholar']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Julie Harris', 'Emily Dickinson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Schilling', 'Tadashi Sawashima']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Yung Carter', 'Anderson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Michel Foucault', 'Ernest Shackleton']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Sandra', 'Claire Bennet']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Octavian', 'Antony']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Evans', 'John Carisi']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Maurice Ravel', 'Sargeant']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Paul Simon', 'Georges']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Daniel Wallace', 'Gery']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Kirk Douglas', 'Marquand']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Sher Shah Suri', 'Humayun']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Van Dorn', 'Ross']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Robert', 'James L. Brooks']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Nick Clegg', 'David Laws']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Matthew', 'John']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Schuyler Miller', 'Finney']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Dick MacPherson', 'Collier']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Sharna Burgess', 'Jenna Johnson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Margaret Tucker', 'Teresa Middleton Clements']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Broughton', 'Travis Browne']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Sudhakar', 'Mangal']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Bram Stoker Award', 'Joe McKinney']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Balog', 'Irving Penn']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Bork', 'Reagan']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['their', 'Curtis', 'Jemmott']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['their', 'Dalton McGuinty', 'Sousa']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['them', 'Monk', 'Roan']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Alice', 'Maya']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Wang', 'Dai']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Rod Stradling', 'Edward II']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['their', 'Webb', 'Danny']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# ...
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Graf', 'Pam Shriver']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Elizabeth', 'Crooke']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Palmer', 'Ida Clough']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Vivien', 'Velma']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Malala', 'Flor']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Tyra Banks', 'Ammerman']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Mount', 'Stella McCartney']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Jane Lane', 'Anne Bagot']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Brittany Pierce', 'Brittany']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Brittany', 'Alma']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Mary Holford', 'Elizabeth Mainwaring']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Violeta Parra', 'Sosa']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Angela', 'Anna']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Sandie Pendleton', "Catherine ``Kate'' Carter Corbin"]:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Azarenka', 'Ana Ivanovic']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Harriet', 'Foote']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Bobbi', 'Edna May']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Olsen', 'Christine Payne']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Isabel', 'Muriel']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Kozlova', 'Anna Kisselgoff']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Rus', 'Mirjana Lu*i*']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Hilary Spurling', 'Delectorskaya']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Peggy Parish', 'Amelia Bedelia']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'MacColl', 'Oscar']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Olga', 'Carol']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Judy Gerstel', 'Mina Shum']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Vernon', 'Ellen']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Teagan', 'Lisa Marie Presley']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Revathi', 'Shilpa Shetty']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Victoria', 'Chloe']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Telma Hopkins', 'Shirley Murdock']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Sabrina Rubin Erdely', 'Kinser']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Sybil Marjorie Cuffe', 'Lady Margaret Joan Lascelles']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Ursula Hegi', 'Patricia Highsmith']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Agnes Meyer', 'Katharine Rhoades']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Ramona', 'Beatrice Quimby']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Tori', 'Beck']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Tori', 'Beck']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Raina Hein', 'White']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Petra', 'Wicked Witch']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Anne Sofie von Berckentin', 'Caroline Matilda']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Martines', 'Stella Lelouch']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Shirazi', 'Delphine Halgand']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Maribel', 'Rosa']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Ray', 'Kelli Hill']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Hema Malini', 'Razia Sultan']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Dent', 'Eleanor Brown']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Rand', 'Ann Corio']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Elizabeth Gaskell', 'Shirley']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Shirley', 'Bront*']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Fiona', 'Nuala Anne']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Vera Lachmann', 'Nelly Sachs']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Maria', 'Johanna']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Holly', 'Juliana']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Bea Feitler', 'Ruth Ansel']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Jeri', 'Gloria']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Gresser', 'Lyudmila Rudenko']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Victoria Mary Clarke', "O'Sullivan"]:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Hazzard', 'Williamson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Violante Beatrice', 'Anna Maria']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Marulanda', 'Marcela Sarmiento']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Sims', 'Jane Annie']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Joanne Evans', 'Naomi']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Overton', 'Amelia Charlesworth']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Rosalind Rosenberg', 'Gildersleeve']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Agnes Nixon', 'Broderick']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Queen Sibylla', 'Constance']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Kate', 'Nora']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Millicent', 'Brooke']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Dian Fossey', 'Agathe Uwilingiyimana']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Eva', 'Vera']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Sarah Dash', 'Patti Scialfa']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Mahon', 'Thompson']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Jenny Jochens', 'Motz']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Kreuk', 'Lana']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Vittoria Capoccii', 'Laura']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Mrs Jacobsson', 'Jane Goodall']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Aretha Franklin', 'Missy Elliott']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Barbra Streisand', 'Ann Powers']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Asma', 'Arwa']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Jovanovski', 'Vera Zvonareva']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Princess Margaret', 'Mary']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Jennie Garth', 'Kelly']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Lady Dedlock', 'Esther']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Liu', 'Gu Long']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Kayla', 'Camryn']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Sanchez', 'Chelsea Caswell']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Catherine', 'Susan Higginbotham']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Elvira', 'Morvan']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Donna', 'Christine']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Norah Lofts', 'Caroline Matilda']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Megan Macqueen', 'Cook']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Silvia', 'Carola']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Mary', 'Thomasine Clopton']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Margaret Tyndal', 'Anne Egerton']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Ruth', 'Naomi']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Dolly', 'Sadie']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Elizabeth Mann', 'Mabel Martha']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Elaine Z. Skinner', 'Civille']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Vivian Colobella', 'Johnson']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Holly Stevens', 'Elsie']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Mia Algotti', 'Miss Foozie']:
# Precision: [0.5, 0.5, 0.5], Recall: [0.5, 0.5, 1.0], F1: [0.5, 0.5, 0.6666666666666666]
# For mentions ['they', 'Goolagong Cawley', 'Venus Williams']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Goolagong Cawley', 'Peggy Michel']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Esther Sheryl Wood', 'Barbara Morgan']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Kayla', 'Natasha Henstridge']:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]
# For mentions ['they', 'Irma', 'Bergen']:
# Precision: [1.0, 1.0, 0.0], Recall: [1.0, 1.0, 0.0], F1: [1.0, 1.0, 0.0]
# For mentions ['they', 'Vicky Austin', "Polly O'Keefe"]:
# Precision: [1.0, 1.0, 0.0], Recall: [0.5, 0.5, 0.0], F1: [0.6666666666666666, 0.6666666666666666, 0.0]

# %%
mentions
# Out:
# ['they', 'Vicky Austin', "Polly O'Keefe"]

# %%
B3_0(mentions, true_clusters, pred_clusters)
# Out:
# ([1.0, 1.0, 0.0], [1.0, 1.0, 0.0], [1.0, 1.0, 0.0])

# %%
gap_file = "gap-test.tsv"
predictions_file = "predictions-test.tsv"
# gap_file = "gap-test-gn.tsv"
# predictions_file = "predictions-test-gn.tsv"

# %%
# Reading GAP DataFrame from a TSV file
gap_df = pd.read_csv(gap_file, sep='\t')
gap_df.rename(columns={'A-coref': 'gold_A-coref', 'B-coref': 'gold_B-coref'},inplace=True)# Reading Predictions DataFrame from a TSV file
predictions_df = pd.read_csv(predictions_file, sep='\t')

# Merge the two DataFrames on the "ID" column
merged_df = pd.merge(gap_df, predictions_df, on='ID')

# Display the first few rows to check
merged_df.head(1)
# Out:
#        ID                                               Text Pronoun  \
# 0  test-1  Upon their acceptance into the Kontinental Hoc...     His
#
#    Pronoun-offset          A  A-offset  gold_A-coref       B  B-offset  \
# 0             383  Bob Suter       352         False  Dehner       366
#
#    gold_B-coref                                         URL  A-coref  B-coref
# 0          True  http://en.wikipedia.org/wiki/Jeremy_Dehner    False     True

# %%
gap_df.head(1)
# Out:
#        ID                                               Text Pronoun  \
# 0  test-1  Upon their acceptance into the Kontinental Hoc...     His
#
#    Pronoun-offset          A  A-offset  gold_A-coref       B  B-offset  \
# 0             383  Bob Suter       352         False  Dehner       366
#
#    gold_B-coref                                         URL
# 0          True  http://en.wikipedia.org/wiki/Jeremy_Dehner

# %%
true_clusters_list, pred_clusters_list, mentions_list, gender_list = generate_clusters_and_mentions(merged_df)
# B3_0(mentions_list, true_clusters_list, pred_clusters_list)

# %%
merged_df
# Out:
#              ID                                               Text Pronoun  \
# 0        test-1  Upon their acceptance into the Kontinental Hoc...     His
# 1        test-2  Between the years 1979-1981, River won four lo...     him
# 2        test-3  Though his emigration from the country has aff...      He
# 3        test-4  At the trial, Pisciotta said: ``Those who have...     his
# 4        test-5  It is about a pair of United States Navy shore...     his
# ...         ...                                                ...     ...
# 1995  test-1996  The sole exception was Wimbledon, where she pl...     She
# 1996  test-1997  According to news reports, both Moore and Fily...     her
# 1997  test-1998  In June 2009, due to the popularity of the Sab...     She
# 1998  test-1999  She was delivered to the Norwegian passenger s...     she
# 1999  test-2000  Meg and Vicky each have three siblings, and ha...     her
#
#       Pronoun-offset                   A  A-offset  gold_A-coref  \
# 0                383           Bob Suter       352         False
# 1                430              Alonso       353          True
# 2                312        Ali Aladhadh       256          True
# 3                526             Alliata       377         False
# 4                406               Eddie       421          True
# ...              ...                 ...       ...           ...
# 1995             479    Goolagong Cawley       400          True
# 1996             338  Esther Sheryl Wood       263          True
# 1997             328               Kayla       364          True
# 1998             305                Irma       255          True
# 1999             275        Vicky Austin       217          True
#
#                        B  B-offset  gold_B-coref  \
# 0                 Dehner       366          True
# 1     Alfredo Di St*fano       390         False
# 2                 Saddam       295         False
# 3              Pisciotta       536          True
# 4            Rock Reilly       559         False
# ...                  ...       ...           ...
# 1995        Peggy Michel       432         False
# 1996      Barbara Morgan       404         False
# 1997  Natasha Henstridge       412         False
# 1998              Bergen       274         False
# 1999       Polly O'Keefe       260         False
#
#                                                     URL  A-coref  B-coref
# 0            http://en.wikipedia.org/wiki/Jeremy_Dehner    False     True
# 1          http://en.wikipedia.org/wiki/Norberto_Alonso     True    False
# 2                 http://en.wikipedia.org/wiki/Aladhadh     True    False
# 3        http://en.wikipedia.org/wiki/Gaspare_Pisciotta    False     True
# 4                  http://en.wikipedia.org/wiki/Chasers     True    False
# ...                                                 ...      ...      ...
# 1995  http://en.wikipedia.org/wiki/Evonne_Goolagong_...     True    False
# 1996  http://en.wikipedia.org/wiki/Hastings_Arthur_Wise     True    False
# 1997          http://en.wikipedia.org/wiki/Raya_Meddine    False    False
# 1998        http://en.wikipedia.org/wiki/SS_Irma_(1905)     True    False
# 1999          http://en.wikipedia.org/wiki/Vicky_Austin     True    False
#
# [2000 rows x 13 columns]

# %%
total_precision_scores = []
total_recall_scores = []
total_f1_scores = []
male_precision_scores = []
male_recall_scores = []
male_f1_scores = []

female_precision_scores = []
female_recall_scores = []
female_f1_scores = []

for mentions, true_clusters, pred_clusters, gender in zip(mentions_list, true_clusters_list, pred_clusters_list, gender_list):
    # print(f"Mentions {mentions}, true clusters {true_clusters}, predicted clusters {pred_clusters}")
    try:
        precision_scores, recall_scores, f1_scores = B3_0(mentions, true_clusters, pred_clusters)
        total_precision_scores += precision_scores
        total_recall_scores += recall_scores
        total_f1_scores += f1_scores

        if gender == 'M':
            male_precision_scores.extend(precision_scores)
            male_recall_scores.extend(recall_scores)
            male_f1_scores.extend(f1_scores)
        elif gender == 'F':
            female_precision_scores.extend(precision_scores)
            female_recall_scores.extend(recall_scores)
            female_f1_scores.extend(f1_scores)
    except:
        print(f"Mentions {mentions}, true clusters {true_clusters}, predicted clusters {pred_clusters}")

# %%
global_precision, global_recall, global_f1 = global_B3_0(total_precision_scores, total_recall_scores, total_f1_scores)

# format the results 
results_str = f"{gap_file} Global B3 Scores:\n"
results_str += f"Precision: {global_precision:.2f}\n"
results_str += f"Recall: {global_recall:.2f}\n"
results_str += f"F1 Score: {global_f1:.2f}"

print(results_str)

# save results to a text file
with open(gap_file+"_global_B3_scores.txt", "w") as f:
    f.write(results_str)
# Out:
# gap-test.tsv Global B3 Scores:
# Precision: 0.60
# Recall: 0.61
# F1 Score: 0.59

# %%
# global scores
global_male_precision, global_male_recall, global_male_f1 = global_B3_0(male_precision_scores, male_recall_scores, male_f1_scores)
global_female_precision, global_female_recall, global_female_f1 = global_B3_0(female_precision_scores, female_recall_scores, female_f1_scores)

#F/M ratio for each metric
precision_ratio = global_female_precision / global_male_precision
recall_ratio = global_female_recall / global_male_recall
f1_ratio = global_female_f1 / global_male_f1

results_str = f"Global B3 Scores:\n"
results_str += f"Male Precision: {global_male_precision:.2f}, Female Precision: {global_female_precision:.2f}, Precision Ratio (F/M): {precision_ratio:.2f}\n"
results_str += f"Male Recall: {global_male_recall:.2f}, Female Recall: {global_female_recall:.2f}, Recall Ratio (F/M): {recall_ratio:.2f}\n"
results_str += f"Male F1: {global_male_f1:.2f}, Female F1: {global_female_f1:.2f}, F1 Ratio (F/M): {f1_ratio:.2f}"

print(results_str)
# Out:
# Global B3 Scores:
# Male Precision: 0.60, Female Precision: 0.60, Precision Ratio (F/M): 1.00
# Male Recall: 0.61, Female Recall: 0.61, Recall Ratio (F/M): 1.01
# Male F1: 0.58, Female F1: 0.59, F1 Ratio (F/M): 1.01
